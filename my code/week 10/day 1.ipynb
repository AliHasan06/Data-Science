# %% [markdown]
# # *Revision*

# %%
# Importing Matplotlib
# Import the `pyplot` module from matplotlib, which provides a convenient interface for plotting. It is conventionally imported as `plt`.
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # learning bar plot

# %%
fig, ax = plt.subplots()

# %%
plt.show()

# %%
x = ['python','java','c++','R']
y = [87,75,80,40]

# %%
plt.bar(x,y , width=0.4, color='pink')
plt.xlabel('langueges',fontsize='20')
plt.ylabel('popularity',fontsize='20')
plt.title('Ali Hasan',fontsize='30')
plt.show()
