# %% [markdown]
# # Training model for Life Expectency dataset

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r'C:\Users\dilib.DESKTOP-GTP80ID\Downloads\Data-Science\Dataset\Life Expectancy Data.csv')

# %%
# Strip whitespace from each column name
data.columns = data.columns.str.strip()
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
data.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Country                            2938
# Year                               2938
# Status                             2938
# Life expectancy                    2928
# Adult Mortality                    2928
# infant deaths                      2938
# Alcohol                            2744
# percentage expenditure             2938
# Hepatitis B                        2385
# Measles                            2938
# BMI                                2904
# under-five deaths                  2938
# Polio                              2919
# Total expenditure                  2712
# Diphtheria                         2919
# HIV/AIDS                           2938
# GDP                                2490
# Population                         2286
# thinness  1-19 years               2904
# thinness 5-9 years                 2904
# Income composition of resources    2771
# Schooling                          2775
# dtype: int64

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
data['GDP']
# Out:
# 0       584.259210
# 1       612.696514
# 2       631.744976
# 3       669.959000
# 4        63.537231
#            ...
# 2933    454.366654
# 2934    453.351155
# 2935     57.348340
# 2936    548.587312
# 2937    547.358878
# Name: GDP, Length: 2938, dtype: float64

# %% [markdown]
# car['horsepower'].fillna(0, inplace=True)
# Alcohol
# Hepatitis B
# Total expenditure
# Income composition of resources
# Schooling

# %%
# Fill the missing values with the median of the column
print(data['Alcohol'].median())
data['Alcohol'].fillna(data['Alcohol'].median(),inplace=True)
# Out:
# 3.755
# C:\Users\dilib.DESKTOP-GTP80ID\AppData\Local\Temp\ipykernel_2208\760525845.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Alcohol'].fillna(data['Alcohol'].median(),inplace=True)

# %%
print(data['Hepatitis B'].median())
data['Hepatitis B'].fillna(data['Hepatitis B'].median(),inplace=True)
# Out:
# 92.0
# C:\Users\dilib.DESKTOP-GTP80ID\AppData\Local\Temp\ipykernel_2208\3684259855.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Hepatitis B'].fillna(data['Hepatitis B'].median(),inplace=True)

# %%
print(data['Total expenditure'].median())
data['Total expenditure'].fillna(data['Total expenditure'].median(),inplace=True)
# Out:
# 5.755
# C:\Users\dilib.DESKTOP-GTP80ID\AppData\Local\Temp\ipykernel_2208\4096868587.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Total expenditure'].fillna(data['Total expenditure'].median(),inplace=True)

# %%
print(data['Income composition of resources'].median())
data['Income composition of resources'].fillna(data['Income composition of resources'].median(),inplace=True)
# Out:
# 0.677
# C:\Users\dilib.DESKTOP-GTP80ID\AppData\Local\Temp\ipykernel_2208\1596738385.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Income composition of resources'].fillna(data['Income composition of resources'].median(),inplace=True)

# %%
print(data['Life expectancy'].median())
data['Life expectancy'].fillna(data['Life expectancy'].median(),inplace=True)
# Out:
# 72.1
# C:\Users\dilib.DESKTOP-GTP80ID\AppData\Local\Temp\ipykernel_2208\1341336314.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Life expectancy'].fillna(data['Life expectancy'].median(),inplace=True)

# %%
data['Life expectancy'].isna().sum()
# Out:
# 0

# %%
print(data['Schooling'].median())
data['Schooling'].fillna(data['Schooling'].median()).count()
# Out:
# 12.3
# 2938

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2938 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness  1-19 years             2904 non-null   float64
#  19  thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2938 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
label_encoder = LabelEncoder()

# %%
# Transform the 'Country' column
data['Country_Code'] = label_encoder.fit_transform(data['Country'])

# Check the result
data[['Country', 'Country_Code']]
# Out:
#           Country  Country_Code
# 0     Afghanistan             0
# 1     Afghanistan             0
# 2     Afghanistan             0
# 3     Afghanistan             0
# 4     Afghanistan             0
# ...           ...           ...
# 2933     Zimbabwe           192
# 2934     Zimbabwe           192
# 2935     Zimbabwe           192
# 2936     Zimbabwe           192
# 2937     Zimbabwe           192
#
# [2938 rows x 2 columns]

# %%
data['Country_Label'] = label_encoder.inverse_transform(data['Country_Code'])


print(data[['Country', 'Country_Code', 'Country_Label']].head())
# Out:
#        Country  Country_Code Country_Label
# 0  Afghanistan             0   Afghanistan
# 1  Afghanistan             0   Afghanistan
# 2  Afghanistan             0   Afghanistan
# 3  Afghanistan             0   Afghanistan
# 4  Afghanistan             0   Afghanistan

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2938 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness  1-19 years             2904 non-null   float64
#  19  thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2938 non-null   float64
#  21  Schooling                        2775 non-null   float64
#  22  Country_Code                     2938 non-null   int32
#  23  Country_Label                    2938 non-null   object
# dtypes: float64(16), int32(1), int64(4), object(3)
# memory usage: 539.5+ KB

# %%
data.head()
data.tail()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 2933             27     4.36                     0.0         68.0       31
# 2934             26     4.06                     0.0          7.0      998
# 2935             25     4.43                     0.0         73.0      304
# 2936             25     1.72                     0.0         76.0      529
# 2937             24     1.68                     0.0         79.0     1483
#
#       ...  Diphtheria  HIV/AIDS         GDP  Population  thinness  1-19 years  \
# 2933  ...        65.0      33.6  454.366654  12777511.0                   9.4
# 2934  ...        68.0      36.7  453.351155  12633897.0                   9.8
# 2935  ...        71.0      39.8   57.348340    125525.0                   1.2
# 2936  ...        75.0      42.1  548.587312  12366165.0                   1.6
# 2937  ...        78.0      43.5  547.358878  12222251.0                  11.0
#
#       thinness 5-9 years  Income composition of resources  Schooling  \
# 2933                 9.4                            0.407        9.2
# 2934                 9.9                            0.418        9.5
# 2935                 1.3                            0.427       10.0
# 2936                 1.7                            0.427        9.8
# 2937                11.2                            0.434        9.8
#
#       Country_Code  Country_Label
# 2933           192       Zimbabwe
# 2934           192       Zimbabwe
# 2935           192       Zimbabwe
# 2936           192       Zimbabwe
# 2937           192       Zimbabwe
#
# [5 rows x 24 columns]

# %%
print(data)
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Diphtheria  HIV/AIDS         GDP  Population  thinness  1-19 years  \
# 0     ...        65.0       0.1  584.259210  33736494.0                  17.2
# 1     ...        62.0       0.1  612.696514    327582.0                  17.5
# 2     ...        64.0       0.1  631.744976  31731688.0                  17.7
# 3     ...        67.0       0.1  669.959000   3696958.0                  17.9
# 4     ...        68.0       0.1   63.537231   2978599.0                  18.2
# ...   ...         ...       ...         ...         ...                   ...
# 2933  ...        65.0      33.6  454.366654  12777511.0                   9.4
# 2934  ...        68.0      36.7  453.351155  12633897.0                   9.8
# 2935  ...        71.0      39.8   57.348340    125525.0                   1.2
# 2936  ...        75.0      42.1  548.587312  12366165.0                   1.6
# 2937  ...        78.0      43.5  547.358878  12222251.0                  11.0
#
#       thinness 5-9 years  Income composition of resources  Schooling  \
# 0                   17.3                            0.479       10.1
# 1                   17.5                            0.476       10.0
# 2                   17.7                            0.470        9.9
# 3                   18.0                            0.463        9.8
# 4                   18.2                            0.454        9.5
# ...                  ...                              ...        ...
# 2933                 9.4                            0.407        9.2
# 2934                 9.9                            0.418        9.5
# 2935                 1.3                            0.427       10.0
# 2936                 1.7                            0.427        9.8
# 2937                11.2                            0.434        9.8
#
#       Country_Code  Country_Label
# 0                0    Afghanistan
# 1                0    Afghanistan
# 2                0    Afghanistan
# 3                0    Afghanistan
# 4                0    Afghanistan
# ...            ...            ...
# 2933           192       Zimbabwe
# 2934           192       Zimbabwe
# 2935           192       Zimbabwe
# 2936           192       Zimbabwe
# 2937           192       Zimbabwe
#
# [2938 rows x 24 columns]

# %%
data.info(
    
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2938 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness  1-19 years             2904 non-null   float64
#  19  thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2938 non-null   float64
#  21  Schooling                        2775 non-null   float64
#  22  Country_Code                     2938 non-null   int32
#  23  Country_Label                    2938 non-null   object
# dtypes: float64(16), int32(1), int64(4), object(3)
# memory usage: 539.5+ KB

# %%
X = data.drop(columns=['Country_Label','Country','Status'],axis=1)

# %%
y = data['Life expectancy']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 1.6217623 , -0.44540826,  0.79023802, ..., -0.73797341,
#         -0.56361393, -1.69104231],
#        [ 1.40498625, -0.98182707,  0.85461353, ..., -0.75260009,
#         -0.59339077, -1.69104231],
#        [ 1.1882102 , -0.98182707,  0.83047271, ..., -0.78185344,
#         -0.62316761, -1.69104231],
#        ...,
#        [-1.19632639, -2.57004747, -0.73868044, ..., -0.99150247,
#         -0.59339077,  1.7231814 ],
#        [-1.41310244, -2.51745739,  4.19409332, ..., -0.99150247,
#         -0.65294445,  1.7231814 ],
#        [-1.62987849, -2.44383128,  4.02510759, ..., -0.95737356,
#         -0.65294445,  1.7231814 ]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2938 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness  1-19 years             2904 non-null   float64
#  19  thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2938 non-null   float64
#  21  Schooling                        2775 non-null   float64
#  22  Country_Code                     2938 non-null   int32
#  23  Country_Label                    2938 non-null   object
# dtypes: float64(16), int32(1), int64(4), object(3)
# memory usage: 539.5+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.009228174603205647
# Mean Squared Error (MSE): 0.0005351181500378609
# Root Mean Squared Error (RMSE): 0.023132620907235328

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='purple')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Life Expectancy')
plt.ylabel('Predicted Life Expectancy')
plt.title('Actual vs Predicted Life Expectancy')
plt.show()
