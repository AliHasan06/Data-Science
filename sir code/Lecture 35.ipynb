# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# **Unsupervised Learning** is a type of machine learning where the algorithm is given data without labeled responses or targets.
#
# It aims to find patterns or structure within the data. In unsupervised learning, the goal is to understand relationships and groupings in the dataset without explicit supervision.

# %% [markdown]
# **Clustering** is one of the most popular unsupervised learning techniques. It involves grouping data points into clusters such that points within the same cluster are more similar to each other than to those in other clusters.

# %% [markdown]
# In **k-means clustering**, the objects are divided into several clusters mentioned by the number ‘K.’ So if we say K = 2, the objects are divided into two clusters, c1 and c2, as shown:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Steps in K-Means Clustering:
#
# - Initialize: Select k initial cluster centers (randomly or using specific techniques).
# - Assignment: Assign each data point to the nearest cluster center.
# - Update: Recalculate the cluster centers as the mean of the assigned points.
# - Repeat until convergence (the cluster centers do not change significantly).

# %%
# Create an example of KMeans clustering

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Create a dataset
data = np.array([[1, 2], [5, 8], [1.5, 1.8], [8, 8], [1, 0.6], [9, 11]])

# Create a KMeans object
kmeans_model = KMeans(n_clusters=2)

# Fit the KMeans object to the data
kmeans_model.fit(data)

# Get the centroids
centroids = kmeans_model.cluster_centers_

# Get the labels
labels = kmeans_model.labels_
# Out:
# c:\Users\dilib.DESKTOP-GTP80ID\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# [[1, 2], [5, 8], [1.5, 1.8], [8, 8], [1, 0.6], [9, 11]]

# %%
# Plot the data and label each data point with its index
colors = ["g.", "r."]
for i in range(len(data)):
    plt.plot(data[i][0], data[i][1], colors[labels[i]], markersize=10)
    plt.text(data[i][0], data[i][1], str(i))
    print("Loop Iteration:", i)
    print("X point", data[i][0])
    print("Y point", data[i][1])
    print("Label from K Means for the X,Y", labels[i])
    print("Centroid for the label", centroids[labels[i]], "\n")

# Plot the centroids and label ea.ch centroid with centroid label
for i in range(len(centroids)):
    plt.plot(centroids[i][0], centroids[i][1], "bx", markersize=10, markeredgewidth=2) # make the X blue and bigger
    plt.text(centroids[i][0], centroids[i][1], "Centroid " + str(i))
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.title("KMeans Clustering")
plt.show()
# Out:
# Loop Iteration: 0
# X point 1.0
# Y point 2.0
# Label from K Means for the X,Y 0
# Centroid for the label [1.16666667 1.46666667]
#
# Loop Iteration: 1
# X point 5.0
# Y point 8.0
# Label from K Means for the X,Y 1
# Centroid for the label [7.33333333 9.        ]
#
# Loop Iteration: 2
# X point 1.5
# Y point 1.8
# Label from K Means for the X,Y 0
# Centroid for the label [1.16666667 1.46666667]
#
# Loop Iteration: 3
# X point 8.0
# Y point 8.0
# Label from K Means for the X,Y 1
# Centroid for the label [7.33333333 9.        ]
#
# Loop Iteration: 4
# X point 1.0
# Y point 0.6
# Label from K Means for the X,Y 0
# Centroid for the label [1.16666667 1.46666667]
#
# Loop Iteration: 5
# X point 9.0
# Y point 11.0
# Label from K Means for the X,Y 1
# Centroid for the label [7.33333333 9.        ]

# %% [markdown]
# - Colors:
# "b": blue
# "g": green
# "r": red
# "c": cyan
# "m": magenta
# "y": yellow
# "k": black
# "w": white
#
# - Markers:
# ".": point
# ",": pixel
# "o": circle
# "v": triangle down
# "^": triangle up
# "<": triangle left
# ">": triangle right
# "1": tri down
# "2": tri up
# "3": tri left
# "4": tri right
# "s": square
# "p": pentagon
# "*": star
# "h": hexagon1
# "H": hexagon2
# "+": plus
# "x": x
# "D": diamond
# "d": thin diamond
# "|": vertical line
# "_": horizontal line

# %%
# Print the centroids
print(centroids)
# Out:
# [[1.16666667 1.46666667]
#  [7.33333333 9.        ]]

# %%
# Print the labels
print(labels)
# Out:
# [0 1 0 1 0 1]

# %%
# Print the prediction of a new point
new_point = np.array([[0, 1]])
print(kmeans_model.predict(new_point))
# Out:
# [0]

# %%
# Print the prediction of a new point
new_point = np.array([[7, 8]])
print(kmeans_model.predict(new_point))
# Out:
# [1]

# %%
# Now lets do it on a dataset from sklearn other than iris and blobs

from sklearn.datasets import load_digits
digits = load_digits()
data = digits.data
labels_original = digits.target

# %%
labels_original.shape
# Out:
# (1797,)

# %%
data.shape
# Out:
# (1797, 64)

# %%
data[0].shape
# Out:
# (64,)

# %%
# visualize the first 10 data points

fig, ax = plt.subplots(2, 5, figsize=(9, 4))
for i, axi in enumerate(ax.flat):
    print(i)
    print(axi)
    axi.imshow(data[i].reshape(8, 8), cmap='binary')
    # cmap='binary' displays the reshaped data as an image in the current subplot using a binary colormap.
    #axi.set(xticks=[], yticks=[])
    #axi.set(xlabel=labels[i])
    axi.set(xticks=[], yticks=[], xlabel=labels_original[i])
plt.show()
# Out:
# 0
# Axes(0.125,0.53;0.133621x0.35)
# 1
# Axes(0.285345,0.53;0.133621x0.35)
# 2
# Axes(0.44569,0.53;0.133621x0.35)
# 3
# Axes(0.606034,0.53;0.133621x0.35)
# 4
# Axes(0.766379,0.53;0.133621x0.35)
# 5
# Axes(0.125,0.11;0.133621x0.35)
# 6
# Axes(0.285345,0.11;0.133621x0.35)
# 7
# Axes(0.44569,0.11;0.133621x0.35)
# 8
# Axes(0.606034,0.11;0.133621x0.35)
# 9
# Axes(0.766379,0.11;0.133621x0.35)

# %%
# now lets cluster the data without using the labels
kmeans_model_digits = KMeans(n_clusters=10)
kmeans_model_digits.fit(data)
# Out:
# KMeans(n_clusters=10)

# %%
# Get the centroids
centroids = kmeans_model_digits.cluster_centers_

# Get the labels
labels_pred = kmeans_model_digits.labels_
print(labels_pred)
# Out:
# [0 3 7 ... 7 8 7]

# %%
# Plot the first 8 data and there predicted label each data point with its index

fig, ax = plt.subplots(2, 4, figsize=(9, 4))
for i, axi in enumerate(ax.flat):
    print(i)
    print(axi)
    axi.imshow(data[i].reshape(8, 8), cmap='binary')
    axi.set(xticks=[], yticks=[], xlabel=labels_pred[i])
plt.show()
# Out:
# 0
# Axes(0.125,0.53;0.168478x0.35)
# 1
# Axes(0.327174,0.53;0.168478x0.35)
# 2
# Axes(0.529348,0.53;0.168478x0.35)
# 3
# Axes(0.731522,0.53;0.168478x0.35)
# 4
# Axes(0.125,0.11;0.168478x0.35)
# 5
# Axes(0.327174,0.11;0.168478x0.35)
# 6
# Axes(0.529348,0.11;0.168478x0.35)
# 7
# Axes(0.731522,0.11;0.168478x0.35)

# %% [markdown]
# **Inertia (Within-Cluster Sum of Squares)**
# - Inertia measures the sum of squared distances between each point and its assigned cluster centroid.
# - It represents how close the data points are within each cluster.
# - A lower value indicates better compactness of clusters.

# %%
inertia = kmeans_model_digits.inertia_
print("Inertia:", inertia)
# Out:
# Inertia: 1168752.8942837543

# %% [markdown]
# The **Silhouette Score** measures how similar a point is to its own cluster (cohesion) compared to other clusters (separation).

# %%
from sklearn.metrics import silhouette_score

# Example: Calculating the Silhouette Score
sil_score = silhouette_score(data, labels_pred)
print("Silhouette Score:", sil_score)
# Out:
# Silhouette Score: 0.18817533615169973

# %% [markdown]
# It ranges from -1 to 1:
# - 1: Perfect clustering, well separated clusters.
# - 0: Overlapping clusters.
# - -1: Incorrect clustering.
#
# A higher silhouette score indicates better-defined clusters.

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(digits.target, predicted_labels)

# Print the confusion matrix
print(conf_matrix)

# Plot the confusion matrix with beautiful colors, also show the values in each cell, keep the colors so that each cell should be visible
plt.matshow(conf_matrix, cmap='coolwarm')
for i in range(10):
    for j in range(10):
        plt.text(j, i, conf_matrix[i, j], ha='center', va='center')
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Calculate the confusion matrix
# ----> 2 conf_matrix = confusion_matrix(digits.target, predicted_labels)
#       4 # Print the confusion matrix
#       5 print(conf_matrix)
#
# NameError: name 'confusion_matrix' is not defined
